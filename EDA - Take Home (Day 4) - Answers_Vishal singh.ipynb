# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="homework.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Take-Home <br>(Day 4)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Life Expectancy Data)
#
# The dataset contains the health data of 2938 individuals useful for predicting the life expentency of the individuals. The features are related to economical factors, immunity realted factors, social factors and so on.
#
# Attribute Information:
#
# **Country:** Country of the recorded data
#
# **Year:** Year of the recorded data
#
# **Status:** Status of the country
#
# **Life expectancy:** Life expectancy in age (target/dependent variable)
#
# **Adult mortality:** Rate of adult mortality
#
# **Infant deaths:** Number of Infant Deaths per 1000 population
#
# **Alcohol:** Alcohol consumption (in litres of pure alcohol)
#
# **Percentage expenditure:** Expenditure on health as a percentage of GDP
#
# **Hepatitis B:** Hepatitis B immunization coverage among 1-year-olds (%)
#
# **Measles:** Number of reported cases per 1000 population
#
# **BMI:** Average BMI of entire population
#
# **Under-five deaths:** Number of under-five deaths per 1000 population
#
# **Polio:** Polio immunization coverage among 1-year-olds (%)
#
# **Total expenditure:** Government expenditure on health as a percentage of total government expenditure (%)
#
# **Diphtheria:** DTP3 immunization coverage among 1-year-olds (%)
#
# **HIV/AIDS:** Deaths per 1000 live births HIV/AIDS (0-4 years)
#
# **GDP:** Gross Domestic Product per capita (in USD)
#
# **Population:** Population of the country
#
# **Thinness 1-19 years:** Prevalence of thinness for age 1 to 19 (%)
#
# **Thinness 5-9 years:** Prevalence of thinness for age 5 to 9 (%)
#
# **Income composition of resources:** Human Development Index in terms of income composition of resources
#
# **Schooling:** Number of years of Schooling

# %% [markdown]
# **Import the required libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load the life expectancy dataset and print the first five observations

# %%
life = pd.read_csv('Life Expectancy Data.csv')
life
# Out:
#           Country  Year      Status  Life expectancy  Adult mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 0                62     0.01               71.279624         65.0     1154
# 1                64     0.01               73.523582         62.0      492
# 2                66     0.01               73.219243         64.0      430
# 3                69     0.01               78.184215         67.0     2787
# 4                71     0.01                7.097109         68.0     3013
# ...             ...      ...                     ...          ...      ...
# 2933             27     4.36                0.000000         68.0       31
# 2934             26     4.06                0.000000          7.0      998
# 2935             25     4.43                0.000000         73.0      304
# 2936             25     1.72                0.000000         76.0      529
# 2937             24     1.68                0.000000         79.0     1483
#
#       ...  Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  \
# 0     ...    6.0               8.16        65.0       0.1  584.259210
# 1     ...   58.0               8.18        62.0       0.1  612.696514
# 2     ...   62.0               8.13        64.0       0.1  631.744976
# 3     ...   67.0               8.52        67.0       0.1  669.959000
# 4     ...   68.0               7.87        68.0       0.1   63.537231
# ...   ...    ...                ...         ...       ...         ...
# 2933  ...   67.0               7.13        65.0      33.6  454.366654
# 2934  ...    7.0               6.52        68.0      36.7  453.351155
# 2935  ...   73.0               6.53        71.0      39.8   57.348340
# 2936  ...   76.0               6.16        75.0      42.1  548.587312
# 2937  ...   78.0               7.10        78.0      43.5  547.358878
#
#       Population  Thinness  1-19 years Thinness 5-9 years  \
# 0       33736494                  17.2               17.3
# 1         327582                  17.5               17.5
# 2       31731688                  17.7               17.7
# 3        3696958                  17.9               18.0
# 4        2978599                  18.2               18.2
# ...          ...                   ...                ...
# 2933    12777511                   9.4                9.4
# 2934    12633897                   9.8                9.9
# 2935      125525                   1.2                1.3
# 2936    12366165                   1.6                1.7
# 2937    12222251                  11.0               11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 22 columns]

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Check the data type of each variable and if any variable is wrongly identified, do the needful</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
life.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult mortality                    float64
# Infant deaths                        int64
# Alcohol                            float64
# Percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
# BMI                                float64
# Under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
# HIV/AIDS                           float64
# GDP                                float64
# Population                          object
# Thinness  1-19 years               float64
# Thinness 5-9 years                 float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Create a DataFrame containing the count and percentage of missing entries in each variable</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
life.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                              16
# Life expectancy                     10
# Adult mortality                     10
# Infant deaths                        0
# Alcohol                            194
# Percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# Under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                           0
# Thinness  1-19 years                34
# Thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
per = ((life.isnull().sum())/len(life))*100

d_per = pd.DataFrame({'null_per': per})

d_per
# Out:
#                                   null_per
# Country                           0.000000
# Year                              0.000000
# Status                            0.544588
# Life expectancy                   0.340368
# Adult mortality                   0.340368
# Infant deaths                     0.000000
# Alcohol                           6.603131
# Percentage expenditure            0.000000
# Hepatitis B                      18.822328
# Measles                           0.000000
# BMI                               1.157250
# Under-five deaths                 0.000000
# Polio                             0.646698
# Total expenditure                 7.692308
# Diphtheria                        0.646698
# HIV/AIDS                          0.000000
# GDP                              15.248468
# Population                        0.000000
# Thinness  1-19 years              1.157250
# Thinness 5-9 years                1.157250
# Income composition of resources   5.684139
# Schooling                         5.547992

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3a. Are there any extreme values present in the government's total expenditure on health?
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.boxplot(life['Total expenditure'])

# Yes, from boxplot it is clear that there are many extreme values present in the government's total expenditure on health
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total expenditure'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3b. Remove the outliers present in 'Total expenditure' using the quartiles of the variable
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
q1 = life['Total expenditure'].quantile(0.25)
q3 = life['Total expenditure'].quantile(0.75)

print('q1 is: ', q1)
print('q3 is: ', q3)

IQR = q3-q1
print('IQR is: ', IQR)

u_limit = q3+1.5*IQR
l_limit = q1-1.5*IQR

print('u_limit is: ', u_limit)
print('l_limit is: ', l_limit)
# Out:
# q1 is:  4.26
# q3 is:  7.4925
# IQR is:  3.2325
# u_limit is:  12.341249999999999
# l_limit is:  -0.5887500000000001

# %%
life[(life['Total expenditure']>u_limit) | (life['Total expenditure']<l_limit)].head(10)
# Out:
#                                Country  Year      Status  Life expectancy  \
# 1386                          Kiribati  2007  Developing             65.0
# 1496                           Liberia  2009  Developing             59.2
# 1573                            Malawi  2012  Developing             55.3
# 1603                          Maldives  2014  Developing             78.2
# 1650                  Marshall Islands  2013  Developing              NaN
# 1700  Micronesia (Federated States of)  2014  Developing             69.4
# 1701  Micronesia (Federated States of)  2013  Developing             69.2
# 1702  Micronesia (Federated States of)  2012  Developing             69.0
# 1703  Micronesia (Federated States of)  2011  Developing             68.9
# 1704  Micronesia (Federated States of)  2010  Developing             68.7
#
#       Adult mortality  Infant deaths  Alcohol  Percentage expenditure  \
# 1386            211.0              0     0.68              188.710877
# 1496            277.0             10     3.75                5.592170
# 1573             42.0             31     0.01               82.768659
# 1603             62.0              0     0.01             2051.748615
# 1650              NaN              0     0.01              871.878317
# 1700            164.0              0     1.58                0.000000
# 1701            166.0              0     1.67                0.000000
# 1702            168.0              0     2.98                0.000000
# 1703            169.0              0     1.89                0.000000
# 1704            171.0              0     1.76                0.000000
#
#       Hepatitis B  Measles  ...  Polio  Total expenditure  Diphtheria  \
# 1386         96.0        0  ...   93.0              13.66        94.0
# 1496         64.0        6  ...   84.0              14.39        81.0
# 1573         96.0       11  ...   95.0              12.60        96.0
# 1603         99.0        0  ...   99.0              13.73        99.0
# 1650          8.0        0  ...   79.0              17.24        79.0
# 1700         81.0      140  ...   76.0              13.71        77.0
# 1701         83.0        0  ...   81.0              13.38        81.0
# 1702         82.0        0  ...   81.0              12.77        81.0
# 1703         83.0        0  ...   83.0              13.76        84.0
# 1704         88.0        0  ...   85.0              13.83        85.0
#
#       HIV/AIDS          GDP  Population  Thinness  1-19 years  \
# 1386       0.1  1357.632211       96311                   0.2
# 1496       2.1    33.667491     3811528                   7.6
# 1573       8.3   374.518820      169735                   6.6
# 1603       0.1  7716.241500          41                  13.6
# 1650       0.1  3617.752354           #                   0.1
# 1700       0.1          NaN           #                   0.2
# 1701       0.1          NaN           #                   0.2
# 1702       0.1          NaN           #                   0.2
# 1703       0.1          NaN           #                   0.2
# 1704       0.1          NaN           #                   0.2
#
#      Thinness 5-9 years  Income composition of resources  Schooling
# 1386                0.1                            0.574       11.8
# 1496                7.4                            0.400        9.7
# 1573                6.5                            0.454       10.7
# 1603               13.7                            0.693       12.7
# 1650                0.1                              NaN        0.0
# 1700                0.2                            0.639       11.7
# 1701                0.2                            0.641       11.7
# 1702                0.2                            0.640       11.7
# 1703                0.2                            0.638       11.7
# 1704                0.2                            0.633       11.5
#
# [10 rows x 22 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Split the data such that 'X' will contain all the indepentdent variables and 'y' will contain the target variable</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Hint:** 'Life expectancy' is the target variable depending on the remaining variables.

# %%
y = pd.DataFrame(life['Life expectancy'])
y
# Out:
#       Life expectancy
# 0                65.0
# 1                59.9
# 2                59.9
# 3                59.5
# 4                59.2
# ...               ...
# 2933             44.3
# 2934             44.5
# 2935             44.8
# 2936             45.3
# 2937             46.0
#
# [2938 rows x 1 columns]

# %%
x = life[life.columns.difference(['Life expectancy'])]
x
# Out:
#       Adult mortality  Alcohol   BMI      Country  Diphtheria         GDP  \
# 0               263.0     0.01  19.1  Afghanistan        65.0  584.259210
# 1               271.0     0.01  18.6  Afghanistan        62.0  612.696514
# 2               268.0     0.01  18.1  Afghanistan        64.0  631.744976
# 3               272.0     0.01  17.6  Afghanistan        67.0  669.959000
# 4               275.0     0.01  17.2  Afghanistan        68.0   63.537231
# ...               ...      ...   ...          ...         ...         ...
# 2933            723.0     4.36  27.1     Zimbabwe        65.0  454.366654
# 2934            715.0     4.06  26.7     Zimbabwe        68.0  453.351155
# 2935             73.0     4.43  26.3     Zimbabwe        71.0   57.348340
# 2936            686.0     1.72  25.9     Zimbabwe        75.0  548.587312
# 2937            665.0     1.68  25.5     Zimbabwe        78.0  547.358878
#
#       HIV/AIDS  Hepatitis B  Income composition of resources  Infant deaths  \
# 0          0.1         65.0                            0.479             62
# 1          0.1         62.0                            0.476             64
# 2          0.1         64.0                            0.470             66
# 3          0.1         67.0                            0.463             69
# 4          0.1         68.0                            0.454             71
# ...        ...          ...                              ...            ...
# 2933      33.6         68.0                            0.407             27
# 2934      36.7          7.0                            0.418             26
# 2935      39.8         73.0                            0.427             25
# 2936      42.1         76.0                            0.427             25
# 2937      43.5         79.0                            0.434             24
#
#       ...  Percentage expenditure  Polio  Population Schooling      Status  \
# 0     ...               71.279624    6.0    33736494      10.1  Developing
# 1     ...               73.523582   58.0      327582      10.0  Developing
# 2     ...               73.219243   62.0    31731688       9.9  Developing
# 3     ...               78.184215   67.0     3696958       9.8  Developing
# 4     ...                7.097109   68.0     2978599       9.5  Developing
# ...   ...                     ...    ...         ...       ...         ...
# 2933  ...                0.000000   67.0    12777511       9.2  Developing
# 2934  ...                0.000000    7.0    12633897       9.5  Developing
# 2935  ...                0.000000   73.0      125525      10.0  Developing
# 2936  ...                0.000000   76.0    12366165       9.8  Developing
# 2937  ...                0.000000   78.0    12222251       9.8  Developing
#
#      Thinness  1-19 years  Thinness 5-9 years  Total expenditure  \
# 0                    17.2                17.3               8.16
# 1                    17.5                17.5               8.18
# 2                    17.7                17.7               8.13
# 3                    17.9                18.0               8.52
# 4                    18.2                18.2               7.87
# ...                   ...                 ...                ...
# 2933                  9.4                 9.4               7.13
# 2934                  9.8                 9.9               6.52
# 2935                  1.2                 1.3               6.53
# 2936                  1.6                 1.7               6.16
# 2937                 11.0                11.2               7.10
#
#       Under-five deaths  Year
# 0                    83  2015
# 1                    86  2014
# 2                    89  2013
# 3                    93  2012
# 4                    97  2011
# ...                 ...   ...
# 2933                 42  2004
# 2934                 41  2003
# 2935                 40  2002
# 2936                 39  2001
# 2937                 39  2000
#
# [2938 rows x 21 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Split the independent variables into two sets with the proportion of 70:30</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
first = life.sample(frac = 0.7)
first
# Out:
#                   Country  Year      Status  Life expectancy  Adult mortality  \
# 2390              Somalia  2002  Developing             58.0            348.0
# 1961               Panama  2013  Developing             77.5            118.0
# 1749              Morocco  2014  Developing             74.1             96.0
# 1688               Mexico  2010  Developing             75.6            127.0
# 77    Antigua and Barbuda  2002  Developing             74.0            153.0
# ...                   ...   ...         ...              ...              ...
# 1915               Norway  2010   Developed             81.0             66.0
# 2648                Tonga  2000  Developing             71.6            158.0
# 2554           Tajikistan  2014  Developing             69.6            162.0
# 1936                 Oman  2005  Developing             74.3            118.0
# 2036          Philippines  2002  Developing             66.8            221.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 2390             47     0.01                0.000000          NaN     9559
# 1961              1     6.89             1694.467075          8.0        0
# 1749             18     0.43              198.734350         99.0       10
# 1688             35     5.21             1033.039737         93.0        0
# 77                0     7.21              927.407585         99.0        0
# ...             ...      ...                     ...          ...      ...
# 1915              0     6.59            15268.064450          NaN        3
# 2648              0     1.24               40.491289         93.0        0
# 2554             10     0.01                7.829009         97.0        0
# 1936              1     0.63              854.011576         99.0       25
# 2036             68     4.42                0.099872         42.0     7003
#
#       ...  Polio  Total expenditure  Diphtheria  HIV/AIDS           GDP  \
# 2390  ...    4.0                NaN         4.0       0.9           NaN
# 1961  ...   81.0               8.90         8.0       0.1  11685.979830
# 1749  ...   99.0               5.91        99.0       0.1   3154.513484
# 1688  ...   95.0               6.39        95.0       0.1   8959.581416
# 77    ...   93.0               4.41        98.0       0.1   9386.716452
# ...   ...    ...                ...         ...       ...           ...
# 1915  ...   93.0               9.26        93.0       0.1  87646.753460
# 2648  ...   91.0               4.75        91.0       0.1    263.272360
# 2554  ...   94.0               6.88        97.0       0.2    114.459190
# 1936  ...   99.0               2.59        99.0       0.1  12376.979360
# 2036  ...   77.0               2.79        79.0       0.1      1.681350
#
#       Population  Thinness  1-19 years Thinness 5-9 years  \
# 2390           #                   7.8                7.6
# 1961     3838462                   1.9                1.9
# 1749     3431882                   6.4                6.2
# 1688   117318941                   1.6                1.6
# 77             #                   3.6                3.5
# ...          ...                   ...                ...
# 1915     4889252                   0.7                0.7
# 2648        9882                   0.1                0.1
# 2554     8362745                   3.6                3.7
# 1936           #                   7.0                6.8
# 2036      813526                   1.0                9.7
#
#       Income composition of resources  Schooling
# 2390                              NaN        NaN
# 1961                            0.773       12.9
# 1749                            0.640       12.1
# 1688                            0.739       12.5
# 77                              0.000        0.0
# ...                               ...        ...
# 1915                            0.936       17.4
# 2648                            0.676       13.7
# 2554                            0.622       11.3
# 1936                            0.742       11.5
# 2036                            0.625       11.4
#
# [2057 rows x 22 columns]

# %%
second = life.drop(first.index)
second
# Out:
#           Country  Year      Status  Life expectancy  Adult mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 9     Afghanistan  2006  Developing             57.3            295.0
# 11    Afghanistan  2004  Developing             57.0            293.0
# 14    Afghanistan  2001  Developing             55.3            316.0
# ...           ...   ...         ...              ...              ...
# 2927     Zimbabwe  2010  Developing             52.4            527.0
# 2928     Zimbabwe  2009  Developing             50.0            587.0
# 2929     Zimbabwe  2008  Developing             48.2            632.0
# 2930     Zimbabwe  2007  Developing             46.6             67.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 0                62     0.01               71.279624         65.0     1154
# 2                66     0.01               73.219243         64.0      430
# 9                84     0.03               17.171518         64.0     1990
# 11               87     0.02               15.296066         67.0      466
# 14               88     0.01               10.574728         63.0     8762
# ...             ...      ...                     ...          ...      ...
# 2927             29     5.21               53.308581          9.0     9696
# 2928             30     4.64                1.040021         73.0      853
# 2929             30     3.56               20.843429         75.0        0
# 2930             29     3.88               29.814566         72.0      242
# 2936             25     1.72                0.000000         76.0      529
#
#       ...  Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  \
# 0     ...    6.0               8.16        65.0       0.1  584.259210
# 2     ...   62.0               8.13        64.0       0.1  631.744976
# 9     ...   58.0               7.43        58.0       0.1  272.563770
# 11    ...    5.0               8.79         5.0       0.1  219.141353
# 14    ...   35.0               7.80        33.0       0.1  117.496980
# ...   ...    ...                ...         ...       ...         ...
# 2927  ...   89.0               5.37        89.0      15.7  713.635620
# 2928  ...   69.0               6.26        73.0      18.1   65.824121
# 2929  ...   75.0               4.96        75.0      20.5  325.678573
# 2930  ...   73.0               4.47        73.0      23.7  396.998217
# 2936  ...   76.0               6.16        75.0      42.1  548.587312
#
#       Population  Thinness  1-19 years Thinness 5-9 years  \
# 0       33736494                  17.2               17.3
# 2       31731688                  17.7               17.7
# 9        2589345                  19.2               19.3
# 11      24118979                  19.5               19.7
# 14       2966463                   2.1                2.4
# ...          ...                   ...                ...
# 2927     1486317                   7.1                7.0
# 2928     1381599                   7.5                7.4
# 2929    13558469                   7.8                7.8
# 2930     1332999                   8.2                8.2
# 2936    12366165                   1.6                1.7
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 2                               0.470        9.9
# 9                               0.405        8.1
# 11                              0.381        6.8
# 14                              0.340        5.9
# ...                               ...        ...
# 2927                            0.436       10.0
# 2928                            0.419        9.9
# 2929                            0.421        9.7
# 2930                            0.414        9.6
# 2936                            0.427        9.8
#
# [881 rows x 22 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. How would you treat the missing values in the variable 'GDP'?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
null_sum = life['GDP'].isnull().sum()

print('null_sum is: ', null_sum)

sns.boxplot(life['GDP'])

median = round(life['GDP'].median(),2)
print('median is: ', median)

# Since, there are lot of outliers in GDP variable so we can treat the missing values in 
# GDP by imputing median into missing values.
# Out:
# null_sum is:  448
# median is:  1766.95
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7.There are 16 observations for which the status of the corresponding country is unknown, impute this status with an appropriate values</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
life['Status'].fillna('Developing', inplace = True)

# %%
life.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult mortality                     10
# Infant deaths                        0
# Alcohol                            194
# Percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# Under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                           0
# Thinness  1-19 years                34
# Thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Define a function to find the extreme values in alcohol consumption
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
from scipy.stats import zscore

life['Alcohol'].isnull().sum()
# Out:
# 0

# %%
a = life['Alcohol'].median()

# %%
life['Alcohol'].fillna(a, inplace = True)

# %%
life['Alcohol'].isnull().sum()
# Out:
# 0

# %%
thres = 3
outliers = []
for i in life['Alcohol']:
    z = (i-(life['Alcohol'].mean()))/(life['Alcohol'].std())
    if z>thres:
        outliers.append(i)
print('Outliers are: ',outliers)
# Out:
# Outliers are:  [16.35, 17.31, 16.99, 17.87, 16.58]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Create a column 'Life_expectancy_level' such that it will contain three levels (High, Medium, Low) based on the life expectancy </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
life['Life expectancy'].describe()
# Out:
# count    2928.000000
# mean       69.224932
# std         9.523867
# min        36.300000
# 25%        63.100000
# 50%        72.100000
# 75%        75.700000
# max        89.000000
# Name: Life expectancy, dtype: float64

# %%
def level(x):
    if x < 60:
        return('Low')
    elif x >= 60 and x <= 75:
        return('Medium')
    else:
        return('High')

# %%
life['Life_expectancy_level'] = life['Life expectancy'].map(level)
life[['Life expectancy','Life_expectancy_level']]
# Out:
#       Life expectancy Life_expectancy_level
# 0                65.0                Medium
# 1                59.9                   Low
# 2                59.9                   Low
# 3                59.5                   Low
# 4                59.2                   Low
# ...               ...                   ...
# 2933             44.3                   Low
# 2934             44.5                   Low
# 2935             44.8                   Low
# 2936             45.3                   Low
# 2937             46.0                   Low
#
# [2938 rows x 2 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Check how life expectancy has changed over the years in China</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
life[life['Country']=='China'][['Year','Life expectancy']]
# Out:
#      Year  Life expectancy
# 560  2015             76.1
# 561  2014             75.8
# 562  2013             75.6
# 563  2012             75.4
# 564  2011             75.2
# 565  2010             75.0
# 566  2009             74.9
# 567  2008             74.5
# 568  2007             74.4
# 569  2006             74.2
# 570  2005             73.9
# 571  2004             73.5
# 572  2003             73.1
# 573  2002             72.7
# 574  2001             72.2
# 575  2000             71.7

# %%
sns.scatterplot(life.loc[life.Country == 'China', 'Year'], life['Life expectancy'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
